# %%
import pandas as pd
import pyarrow 


df = pd.read_parquet('reklamation24_transport-logistik-full/data/train-00000-of-00001-2966d8d294aca31a.parquet' ,engine='pyarrow')

# %%
df
# Out:
#                                                    text  \
# 0     \n                                Die große GH...
# 1     \n                                Lieferung 3 ...
# 2     \n                                Radwege frei...
# 3     \n                                Nach Ende La...
# 4     \n                                Abstellgeneh...
# ...                                                 ...
# 6701  \n                                Paketbote gi...
# 6702  \n                                Briefmarken ...
# 6703  \n                                Paket wegen ...
# 6704  \n                                Zuhause gewe...
# 6705  \n                                Pakete im st...
#
#                                                  inputs  \
# 0     {'text': '
#                                 Die...
# 1     {'text': '
#                                 Lie...
# 2     {'text': '
#                                 Rad...
# 3     {'text': '
#                                 Nac...
# 4     {'text': '
#                                 Abs...
# ...                                                 ...
# 6701  {'text': '
#                                 Pak...
# 6702  {'text': '
#                                 Bri...
# 6703  {'text': '
#                                 Pak...
# 6704  {'text': '
#                                 Zuh...
# 6705  {'text': '
#                                 Pak...
#
#                                              prediction prediction_agent  \
# 0     [{'label': 'Kontogutschrift', 'score': 0.05535...         titan230
# 1     [{'label': 'Lieferung', 'score': 0.12633491997...         titan230
# 2     [{'label': 'Fahrplanauskunft', 'score': 0.1722...         titan230
# 3     [{'label': 'Terminvereinbarung', 'score': 0.09...         titan230
# 4     [{'label': 'Kontoschließung', 'score': 0.11904...         titan230
# ...                                                 ...              ...
# 6701  [{'label': 'Kontakt-Unterlassung', 'score': 0....         titan230
# 6702  [{'label': 'Kontogutschrift', 'score': 0.30174...         titan230
# 6703  [{'label': 'Kontogutschrift', 'score': 0.07353...         titan230
# 6704  [{'label': 'Fahrplanauskunft', 'score': 0.1714...         titan230
# 6705  [{'label': 'Lieferung', 'score': 0.10198502316...         titan230
#
#                  annotation annotation_agent  \
# 0                      None             None
# 1              Lieferverzug          argilla
# 2          Kundenbeschwerde          argilla
# 3              Lieferverzug          argilla
# 4     Mitarbeiterbeschwerde          argilla
# ...                     ...              ...
# 6701                   None             None
# 6702                   None             None
# 6703                   None             None
# 6704                   None             None
# 6705                   None             None
#
#                                                 vectors  multi_label  \
# 0     {'mini-lm-sentence-transformers': [-0.08034356...        False
# 1     {'mini-lm-sentence-transformers': [-0.16730995...        False
# 2     {'mini-lm-sentence-transformers': [0.140555530...        False
# 3     {'mini-lm-sentence-transformers': [-0.14903360...        False
# 4     {'mini-lm-sentence-transformers': [0.046514205...        False
# ...                                                 ...          ...
# 6701  {'mini-lm-sentence-transformers': [0.164023548...        False
# 6702  {'mini-lm-sentence-transformers': [-0.14580729...        False
# 6703  {'mini-lm-sentence-transformers': [-0.05140902...        False
# 6704  {'mini-lm-sentence-transformers': [0.179809138...        False
# 6705  {'mini-lm-sentence-transformers': [0.122975900...        False
#
#      explanation                                    id metadata     status  \
# 0           None  00064c8b-2307-4932-a141-9a6d37f33977     None  Discarded
# 1           None  000ae7e2-09bf-4b11-8006-a53a34f29262     None  Validated
# 2           None  001dc075-7f38-4ba9-b3c8-ff8a44cbfd7c     None  Validated
# 3           None  00235251-41c5-4502-bf2f-9e6e8be1b09c     None  Validated
# 4           None  00240bfc-7823-46c3-8d77-0a32b52010cc     None  Validated
# ...          ...                                   ...      ...        ...
# 6701        None  ffb1b236-c725-425f-ad8b-99012bafe33a     None    Default
# 6702        None  ffde00fc-6279-4ed3-b572-b29d10c4caae     None    Default
# 6703        None  ffecb8a3-c7e4-43d3-b5fa-aea64e071b14     None    Default
# 6704        None  fff07693-38d7-4ace-b58d-e66d597d376c     None    Default
# 6705        None  fff6bb75-cf7a-4c78-b8f8-c73d2bdd2286     None    Default
#
#                 event_timestamp                metrics
# 0    2023-03-11 17:11:06.762102  {'text_length': 1064}
# 1    2023-03-11 17:11:03.472191   {'text_length': 470}
# 2    2023-03-11 17:11:04.299987   {'text_length': 706}
# 3    2023-03-11 17:11:07.534691   {'text_length': 629}
# 4    2023-03-11 17:11:02.095025   {'text_length': 414}
# ...                         ...                    ...
# 6701 2023-03-11 17:11:06.570525   {'text_length': 671}
# 6702 2023-03-11 17:11:07.550344   {'text_length': 536}
# 6703 2023-03-11 17:11:04.898347   {'text_length': 249}
# 6704 2023-03-11 17:11:01.926715   {'text_length': 765}
# 6705 2023-03-11 17:11:06.353604   {'text_length': 379}
#
# [6706 rows x 14 columns]
